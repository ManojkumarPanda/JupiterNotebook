# %%
# %%html
# <div>
#     <iframe width="80%" height="692" src="https://www.youtube.com/embed/m1dl_mrk5Rk" title="Lecture:- 01 || Machine Learning Fundamentals || FSMLC" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# </div>
# Out:
# <div>
#     <iframe width="80%" height="692" src="https://www.youtube.com/embed/m1dl_mrk5Rk" title="Lecture:- 01 || Machine Learning Fundamentals || FSMLC" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# </div>

# %% [raw]
# Resorces : https://wheat-production-d58.notion.site/ML002-e469d005b2b14d5ba6f8c0bdfd305ded

# %%
print('hi')
